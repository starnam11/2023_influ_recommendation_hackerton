# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 분류기를 통과한 데이터 병합을 위한 호출

# %%
df1 = pd.read_csv('/content/drive/MyDrive/woman_influ_season_tag.csv')
df2 = pd.read_csv('/content/drive/MyDrive/woman_influ_style_tag.csv')
df3 = pd.read_csv('/content/drive/MyDrive/woman_influ_tone_tag.csv')

# %%
df1
# Out:
#      Unnamed: 0          influ_id                  influ_pic_id  season
# 0             0    @belleofcloset     @belleofcloset_9_half.png  winter
# 1             1  @__v.yuum_look__  @__v.yuum_look___12_half.png  winter
# 2             2     @98.c_project     @98.c_project_12_half.png  autumn
# 3             3  @__v.yuum_look__   @__v.yuum_look___9_half.png  winter
# 4             4            @kxyxn            @kxyxn_20_half.png  summer
# ..          ...               ...                           ...     ...
# 616         616            @kxyxn             @kxyxn_8_half.png  autumn
# 617         617  @__v.yuum_look__   @__v.yuum_look___4_half.png  winter
# 618         618    @belleofcloset     @belleofcloset_4_half.png  autumn
# 619         619           __02x02            __02x02_4_half.png  summer
# 620         620       @antmousbe9        @antmousbe9_3_half.png  autumn
#
# [621 rows x 4 columns]

# %%
df2
# Out:
#      Unnamed: 0          influ_id                  influ_pic_id     style
# 0             0    @belleofcloset     @belleofcloset_9_half.png  romantic
# 1             1  @__v.yuum_look__  @__v.yuum_look___12_half.png  romantic
# 2             2     @98.c_project     @98.c_project_12_half.png    casual
# 3             3  @__v.yuum_look__   @__v.yuum_look___9_half.png    formal
# 4             4            @kxyxn            @kxyxn_20_half.png    casual
# ..          ...               ...                           ...       ...
# 616         616            @kxyxn             @kxyxn_8_half.png    casual
# 617         617  @__v.yuum_look__   @__v.yuum_look___4_half.png      chic
# 618         618    @belleofcloset     @belleofcloset_4_half.png    casual
# 619         619           __02x02            __02x02_4_half.png    casual
# 620         620       @antmousbe9        @antmousbe9_3_half.png   girlish
#
# [621 rows x 4 columns]

# %%
df3
# Out:
#      Unnamed: 0          influ_id                  influ_pic_id     tone
# 0             0    @belleofcloset     @belleofcloset_9_half.png     mono
# 1             1  @__v.yuum_look__  @__v.yuum_look___12_half.png     mono
# 2             2     @98.c_project     @98.c_project_12_half.png   pastel
# 3             3  @__v.yuum_look__   @__v.yuum_look___9_half.png   toneon
# 4             4            @kxyxn            @kxyxn_20_half.png     mono
# ..          ...               ...                           ...      ...
# 616         616            @kxyxn             @kxyxn_8_half.png     mono
# 617         617  @__v.yuum_look__   @__v.yuum_look___4_half.png  neutral
# 618         618    @belleofcloset     @belleofcloset_4_half.png   pastel
# 619         619           __02x02            __02x02_4_half.png     mono
# 620         620       @antmousbe9        @antmousbe9_3_half.png   pastel
#
# [621 rows x 4 columns]

# %% [markdown]
# # 분류 결과를 모두 담은 최종 Output DataFrame Concat

# %%
final_df = pd.DataFrame(columns = ['influ_id','influ_pic_id','style','tone','season'])

# %%
final_df['influ_id']=df1['influ_id']

# %%
final_df['influ_pic_id'] = df1['influ_pic_id']

# %%
final_df['style'] = df2['style']

# %%
final_df['tone'] = df3['tone']

# %%
final_df['season'] = df1['season']

# %%
final_df.to_csv('/content/drive/MyDrive/2023 KUIAI 해커톤/final_woman_influ.csv')
