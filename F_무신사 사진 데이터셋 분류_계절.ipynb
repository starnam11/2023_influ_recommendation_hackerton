# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 필요한 모듈 import
import pandas as pd
import os, shutil, ast
from pathlib import Path

# %%
half_path = Path('/content/drive/MyDrive/2023 KUIAI 해커톤/Data/Season/woman')

# %%
half_path_list = list(half_path.glob(r'**/*.jpg'))

# %%
# 남성, 여성에 해당하는 Database csv 파일 불러오기
man = pd.read_csv('/content/drive/MyDrive/2023 KUIAI 해커톤/Data/Man/Man.csv', encoding = 'cp949', index_col = 0)
woman = pd.read_csv('/content/drive/MyDrive/2023 KUIAI 해커톤/Data/Woman/Woman.csv', encoding = 'cp949', index_col = 0)

# %%
for i in range(len(man)):
  tag_list = man['tags_list'].iloc[i]
  tag_list = ast.literal_eval(tag_list)
  man['tags_list'].iloc[i] = tag_list
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
man
# Out:
#       image_id      title                                          tags_list  \
# 0        31162     스트릿 패션  [#겨울, #스트릿, #컬러포인트, #글로시, # 카고, # 와이드핏, #컬러블록,...
# 1        31161     아메카지 룩  [#겨울, #아메리칸 캐주얼, # 퀼팅, # 와이드핏, #핀턱, #컬러포인트, # ...
# 2        31160    유니크한 조합  [#겨울, #스트릿, #컬러포인트, #레터링, # 코듀로이, # 플라워, #페이즐리...
# 3        31159     캐주얼 무드  [#겨울, #캐주얼, #얼죽코, # 싱글코트, #컬러블록, # 워싱, # 와이드핏,...
# 4        31158      데일리하게  [#겨울, #캐주얼, #스티치, # 그래픽, #언밸런스, # 와이드핏, #니트/스웨...
# ...        ...        ...                                                ...
# 2061     26762     스포티 무드  [#컬러포인트, #컬러블록, #레터링, #로고플레이, #스포티, #레저스포츠, #슬...
# 2062     26761  캠핑 룩으로 제격  [#페이즐리, #오버핏, #캠핑, #봄, #아메리칸 캐주얼, #그라미치, #츄바스코...
# 2063     26760    깔끔한 스타일  [#스트라이프, #컬러블록, #꾸안꾸, #봄, #캐주얼, #그라미치, #리복 워치,...
# 2064     26759   따라 입어 봐!  [#펀칭, #오버핏, #크롭, #톤온톤, #뉴트럴톤, #봄, #캐주얼, #반스, #...
# 2065     26758     시티보이 룩  [#오버핏, #컬러포인트, #시티보이룩, #피크닉, #봄, #아메리칸 캐주얼, #무...
#
#      name  gender      style
# 0     김성주       1       #스트릿
# 1     김성주       1  #아메리칸 캐주얼
# 2     김성주       1       #스트릿
# 3     김성주       1       #캐주얼
# 4     김성주       1       #캐주얼
# ...   ...     ...        ...
# 2061  윤지욱       1        #골프
# 2062  윤지욱       1  #아메리칸 캐주얼
# 2063  윤지욱       1       #캐주얼
# 2064  윤지욱       1       #캐주얼
# 2065  윤지욱       1  #아메리칸 캐주얼
#
# [2066 rows x 6 columns]

# %%
man['season'].value_counts()
# Out:
# #여름    809
# #겨울    590
# #가을    523
# #봄     141
# 0        3
# Name: season, dtype: int64

# %%
# '#style'과 이미지 파일을 이동할 폴더명을 dict type으로 매칭하여 변수에 저장
folder_match_dict = {'#봄':'spring',
 '#여름':'summer',
 '#가을':'autumn',
 '#겨울':'winter'
}

# %%
man['season'] = 0

for i in range(len(man)):
  if '#봄' in man['tags_list'].iloc[i]:
    man['season'].iloc[i] = '#봄'
  elif '#여름' in man['tags_list'].iloc[i]:
    man['season'].iloc[i] = '#여름'
  elif '#가을' in man['tags_list'].iloc[i]:
    man['season'].iloc[i] = '#가을'
  elif '#겨울' in man['tags_list'].iloc[i]:
    man['season'].iloc[i] = '#겨울'
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
man['tags_list'].iloc[0]
# Out:
# ['#겨울',
#  '#스트릿',
#  '#컬러포인트',
#  '#글로시',
#  '# 카고',
#  '# 와이드핏',
#  '#컬러블록',
#  '# 퀼팅',
#  '#유니크',
#  '#긴소매 티셔츠',
#  '#데님 팬츠',
#  '#디앤에스알',
#  '#베스트',
#  '#선글라스',
#  '#숏패딩/숏헤비 아우터',
#  '#에러스익셉티드',
#  '#유니폼브릿지',
#  '#이티씨이',
#  '#장갑',
#  '#척',
#  '#캡/야구 모자',
#  '#투큐브',
#  '#패션스니커즈화',
#  '#프로스펙스',
#  '#피스메이커']

# %%
# 기존 크롤링한 이미지 파일들이 저장된 폴더 경로
path_before = '/content/drive/MyDrive/2023 KUIAI 해커톤/Data/man_half/'

# 남성에 해당하는 이미지 파일의 이름들을 list type에 저장
list_jpg = list(man['image_id'])

# 반복문을 통해 각 이미지 파일이 style에 맞는 폴더로 복사/이동
for i in range(len(list_jpg)):
  num = list_jpg[i]
  line = man[man['image_id'] == num]

  season = list(man[man['image_id'] == num]['season'])[0]

  if season == 0:
    continue

  # 이동할 이미지 파일 경로
  img_name = str(num) + '_half.jpg'
  if img_name not in os.listdir(path_before):
    continue 
  file_path = path_before + img_name

  # 이동 시킬 폴더 경로
  move_folder_path = '/content/drive/MyDrive/2023 KUIAI 해커톤/Data/Season/man/' + folder_match_dict[season]
  shutil.copy(file_path, move_folder_path)

# %%
woman[woman['image_id'] == num]['season']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'season'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-36dae4721f9a> in <module>
# ----> 1 woman[woman['image_id'] == num]['season']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'season'

# %%
woman
# Out:
#       image_id      title                                          tags_list  \
# 0        31122  편안하고 멋스럽게  ['#겨울', '#캐주얼', '#라츠유', '#바인듀', '#반지', '#부츠', ...
# 1        31121    데일리로 좋아  ['#겨울', '#캐주얼', '#겨울 기타 코트', '#글림퍼', '#더블유엠엠스튜...
# 2        31120      감각적이야  ['#걸리시', '#겨울', '#긴소매 티셔츠', '#러브참', '#모트', '#믐...
# 3        31119  올 블랙 스타일링  ['#걸리시', '#겨울', '#겨울 싱글 코트', '#라퍼지스토어', '#로우클래...
# 4        31117    귀여운 디테일  ['#걸리시', '#겨울', '#겨울 더블 코트', '#뮤제아르', '#미니스커트'...
# ...        ...        ...                                                ...
# 2268     26771   러블리 OOTD  ['#화사한', '#셔링', '#파스텔', '#봄', '#걸리시', '#여섯시십칠분...
# 2269     26770    디테일의 차이  ['#슬림핏', '#컬러포인트', '#키높이', '#봄', '#걸리시', '#스틸 ...
# 2270     26769      매력적이야  ['#그라데이션', '#크롭', '#컬러포인트', '#슬릿', '#키높이', '#봄...
# 2271     26768     자신감 넘쳐  ['#크롭', '#그래픽', '#찢청', '#유니크', '#봄', '#스트릿', '...
# 2272     26767     예쁨 주의보  ['#로고플레이', '#크롭', '#스퀘어넥', '#짧치', '#스티치', '#키높...
#
#      name  gender style
# 0     김유빈       0  #캐주얼
# 1     김유빈       0  #캐주얼
# 2     김유빈       0  #걸리시
# 3     김유빈       0  #걸리시
# 4     김유빈       0  #걸리시
# ...   ...     ...   ...
# 2268  이유진       0  #걸리시
# 2269  이유진       0  #걸리시
# 2270  이유진       0  #걸리시
# 2271  이유진       0  #스트릿
# 2272  이유진       0  #걸리시
#
# [2273 rows x 6 columns]

# %%
woman['style'].value_counts()
# Out:
# #캐주얼         666
# #걸리시         488
# 0            259
# #로맨틱         235
# #스트릿         174
# #골프          145
# #시크          118
# #포멀           86
# #스포츠          55
# #레트로          24
# #댄디           20
# #아메리칸 캐주얼      3
# Name: style, dtype: int64

# %%
# 여성의 이미지 데이터도 남성의 경우와 동일하게 진행

path_before = '/content/drive/MyDrive/2023 KUIAI 해커톤/pic/'

list_jpg = list(woman['image_id'])

for i in range(len(list_jpg)):
  num = list_jpg[i]
  line = woman[woman['image_id'] == num]

  style = list(woman[woman['image_id'] == num]['style'])[0]

  if style == '0':
    continue

  # 이동할 이미지 파일 경로
  file_path = path_before + str(num) + '.jpg'

  # 이동 시킬 폴더 경로
  move_folder_path = '/content/drive/MyDrive/2023 KUIAI 해커톤/Data/Woman/' + folder_match_dict[style]
  shutil.copy(file_path, move_folder_path)
