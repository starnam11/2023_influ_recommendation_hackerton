# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 분류기를 통과한 각각의 남성 사진 결과 호출

# %%
df1 = pd.read_csv('/content/drive/MyDrive/2023 KUIAI 해커톤/man_influ_season_tag.csv')
df2 = pd.read_csv('/content/drive/MyDrive/2023 KUIAI 해커톤/influ_style_tag2.csv')
df3 = pd.read_csv('/content/drive/MyDrive/2023 KUIAI 해커톤/man_influ_tone_tag.csv')

# %%
df1
# Out:
#      Unnamed: 0    influ_id            influ_pic_id  season
# 0             0    @one_r_k     @one_r_k_3_half.png  autumn
# 1             1   @oohsehun    @oohsehun_3_half.png  summer
# 2             2  @zxcvr0626  @zxcvr0626_11_half.png  winter
# 3             3   @j0ng_wo0    @j0ng_wo0_3_half.png  summer
# 4             4   @hmm.__.u   @hmm.__.u_22_half.png  summer
# ..          ...         ...                     ...     ...
# 786         786  @zxcvr0626  @zxcvr0626_20_half.png  winter
# 787         787   @__my_t__   @__my_t___27_half.png  summer
# 788         788     @d_soms      @d_soms_4_half.png  autumn
# 789         789    @oytoyt_     @oytoyt__2_half.png  winter
# 790         790   @hmm.__.u   @hmm.__.u_13_half.png  autumn
#
# [791 rows x 4 columns]

# %%
df2
# Out:
#      Unnamed: 0    influ_id            influ_pic_id   style
# 0             0    @one_r_k     @one_r_k_3_half.png  street
# 1             1   @oohsehun    @oohsehun_3_half.png   loose
# 2             2  @zxcvr0626  @zxcvr0626_11_half.png  street
# 3             3   @j0ng_wo0    @j0ng_wo0_3_half.png  street
# 4             4   @hmm.__.u   @hmm.__.u_22_half.png  formal
# ..          ...         ...                     ...     ...
# 786         786  @zxcvr0626  @zxcvr0626_20_half.png  street
# 787         787   @__my_t__   @__my_t___27_half.png  street
# 788         788     @d_soms      @d_soms_4_half.png  street
# 789         789    @oytoyt_     @oytoyt__2_half.png   loose
# 790         790   @hmm.__.u   @hmm.__.u_13_half.png  street
#
# [791 rows x 4 columns]

# %%
df3
# Out:
#      Unnamed: 0    influ_id            influ_pic_id     tone
# 0             0    @one_r_k     @one_r_k_3_half.png     mono
# 1             1   @oohsehun    @oohsehun_3_half.png     mono
# 2             2  @zxcvr0626  @zxcvr0626_11_half.png  neutral
# 3             3   @j0ng_wo0    @j0ng_wo0_3_half.png     mono
# 4             4   @hmm.__.u   @hmm.__.u_22_half.png     mono
# ..          ...         ...                     ...      ...
# 786         786  @zxcvr0626  @zxcvr0626_20_half.png     mono
# 787         787   @__my_t__   @__my_t___27_half.png     mono
# 788         788     @d_soms      @d_soms_4_half.png  neutral
# 789         789    @oytoyt_     @oytoyt__2_half.png     mono
# 790         790   @hmm.__.u   @hmm.__.u_13_half.png     mono
#
# [791 rows x 4 columns]

# %% [markdown]
# # 분류기를 통과한 사진들 결과 병합

# %%
final_df = pd.DataFrame(columns = ['influ_id','influ_pic_id','style','tone','season'])

# %%
final_df['influ_id']=df1['influ_id']

# %%
final_df['influ_pic_id'] = df1['influ_pic_id']

# %%
final_df['style'] = df2['style']

# %%
final_df['tone'] = df3['tone']

# %%
final_df['season'] = df1['season']

# %%
final_df.to_csv('/content/drive/MyDrive/2023 KUIAI 해커톤/final_man_influ2.csv')
